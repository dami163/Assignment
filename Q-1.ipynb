# %% [markdown]
# <a href="https://colab.research.google.com/github/dami163/Assignment/blob/main/Q-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#load image
img = cv.imread('margot_golden_gray.jpg', cv.IMREAD_GRAYSCALE)

c = np.array([(220, 175), (220, 210), (255, 240)])

t1 = np.linspace(0, c[0, 1], c[0, 0]+1).astype('uint8')
print(len(t1))
t2 = np.linspace(c[0, 1] + 1, c[1, 0]-c[0, 0], c[1, 0]-c[0, 0]).astype('uint8')
print(len(t2))
t3 = np.linspace(c[1, 1] + 1, 245, 255 - c[1, 0]).astype('uint8')
print(len(t3))

transform = np.concatenate((t1, t2, t3), axis=0).astype('uint8')
print(len(transform))

# reshape the transform to (256, 1)
transform = transform.reshape(256, 1)
print(transform.shape)

fig, ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input intensity')
ax.set_ylabel('Output intensity')
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_aspect('equal')
plt.show()

image_transformed = cv.LUT(img, transform)

fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(img, cmap="gray")
ax[0].set_title("Original")
ax[0].axis('off')
ax[1].imshow(image_transformed, cmap="gray")
ax[1].set_title("Transformed")
ax[1].axis('off')
plt.show()
# Out:
# 221
# 0
# 35
# 256
# (256, 1)

# %% [markdown]
# # New section
